# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejith1/vrsu/blob/main/vrsulab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("/content/WhatsApp Image 2025-12-09 at 10.38.27 AM.jpeg",0)

clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
clahe_img=clahe.apply(img)
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(img,cmap="Purples")
plt.axis("Off")

plt.subplot(1,2,2)
plt.title("CLAHE Enhanced")
plt.imshow(clahe_img,cmap="gray")
plt.axis("Off")

plt.show()
